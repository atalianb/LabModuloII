# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
ran_x = np.random.uniform(0.,1.4,1000)
ran_y = np.random.uniform(0.,1.4,1000)

# %%
plt.plot(ran_x,ran_y,'.')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
theta = np.random.random(1000)*2.*np.pi
r1 = np.random.uniform(0.0,0.5,1000)
r = np.sqrt(r1)#**(0.5)
x = r*np.cos(theta) +0.7
y = r*np.sin(theta) + 0.7
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.plot(ran_x,ran_y,'.')
plt.plot(x,y,'.')
plt.show()

# %%
def distancia(x1,x2,y1,y2):
    d = np.sqrt((x2 - x1)**2 + (y2-y1)**2)
    return d

# %%
dis_data = []
dis_ran = []

# %%
for i in range(len(x)):
    for j in range(i+1,len(x)):
        d_d = distancia(x[i],x[j],y[i],y[j])
        d_r = distancia(ran_x[i],ran_x[j],ran_y[i],ran_y[j])
        dis_data.append(d_d)
        dis_ran.append(d_r)

# %%
data_n, data_bin,m = plt.hist(dis_data,bins=20)

# %%
ran_n, ran_bin, p = plt.hist(dis_ran,bins=20)

# %% [markdown]
# Función de Correlación de Peebles $\frac{DD(r)}{RR(r)} - 1$

# %%
plt.plot(data_bin[1:],(data_n/ran_n) -1)

# %% [markdown]
# Para la función de correlación de Hamilton $\psi_{H}^{2} = \frac{DD(r)RR(r)}{(DR(r))^{2}}$

# %%
dis_dr = []

# %%
for i in range(len(x)):
    for j in range(len(x)):
        d_dr = distancia(x[i],ran_x[j],y[i],ran_y[j])
        dis_dr.append(d_dr)

# %%
dr_n, dr_bin, q = plt.hist(dis_dr,bins=20)

# %%
plt.plot(data_bin[1:],(data_n*ran_n)/(dr_n)**2)

# %% [markdown]
# Para la función de correlación de Landy-Szalay $1 + \frac{DD(r)}{RR(r)} -2\frac{DR(r)}{RR(r)} $

# %%
plt.plot(data_bin[1:],1.+ data_n/ran_n -2*dr_n/ran_n)

# %%
theta = np.random.random(1000)*2.*np.pi
r = np.random.uniform(0.0,0.5,1000)
#r = r1**(1/2)
x1 = r*np.cos(theta) + 0.5
y1 = r*np.sin(theta) + 0.5
plt.plot(x1,y1,'.')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
ran_x_1 = np.random.uniform(0.,1.,1000)
ran_y_1 = np.random.uniform(0.,1.,1000)

# %%
dis_data1 = []
dis_ran1 = []

# %%
for i in range(len(x)):
    for j in range(i+1,len(x)):
        d_d = distancia(x1[i],x1[j],y1[i],y1[j])
        d_r = distancia(ran_x_1[i],ran_x_1[j],ran_y_1[i],ran_y_1[j])
        dis_data1.append(d_d)
        dis_ran1.append(d_r)

# %%
data_n_1, data_bin_1,g = plt.hist(dis_data,bins=20)

# %%
ran_n_1, ran_bin_1, h = plt.hist(dis_ran,bins=20)

# %%
plt.plot(data_bin[1:],(data_n_1/ran_n_1) -1)

# %%
dis_dr_1 = []

for i in range(len(x)):
    for j in range(len(x)):
        d_dr = distancia(x1[i],ran_x_1[j],y1[i],ran_y_1[j])
        dis_dr_1.append(d_dr)

dr_n_1, dr_bin_1, w = plt.hist(dis_dr,bins=20)

# %%
plt.plot(data_bin[1:],(data_n_1*ran_n_1)/(dr_n_1)**2)

# %%
plt.plot(data_bin_1[1:],1.+ data_n_1/ran_n_1 -2*dr_n_1/ran_n_1)
